# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By 
import pandas as pd
import os

# %% [markdown]
# # Scraping the data

# %%
# Start chrome in background without any visual output or windows
options = Options()
options.add_argument("--headless")
options.add_argument("--window-size=1920,1200")

# Initialize the driver
driver = webdriver.Chrome(options=options,service=Service(ChromeDriverManager().install()))
# Out:
# [WDM] - Downloading: 100%|██████████| 6.78M/6.78M [00:01<00:00, 3.72MB/s]

# %%
def physical_attributes(nested_list):
    '''
    This function takes in a list of dictionaries, loops through it and
    appends the physical attributes scraped from the characters to it
    '''
    physical_atts = ['species', 'gender', 'hair colour', 'eye colour','skin colour']
    for atts in physical_atts:
        for value in nested_list:
            try: 
                driver.get(value['url'])
                titles = driver.find_elements(By.XPATH, '//*[@id="mw-content-text"]/div/aside/section[3]/div/h3')
                attributes = driver.find_elements(By.XPATH, f'//*[@id="mw-content-text"]/div/aside/section[3]/div[{physical_atts.index(atts)+1}]/div')
                for title in titles:
                    if title.text.lower() == atts:
                        for attribute in attributes:
                            value[atts] = attribute.text
            except:
                pass
    return nested_list

# %%
# Scrape for the hogwarts staff
driver.get('https://harrypotter.fandom.com/wiki/Hogwarts_Legacy')
staff = driver.find_elements(By.XPATH, '//*[@id="mw-content-text"]/div/ul[6]/li/a[1]')
hogwarts_staff = []
for value in staff:
    hogwarts_staff.append({
        'name': value.text,
        'url':value.get_attribute('href'),
        'species': None,
        'gender': None,
        'hair colour': None,
        'eye colour': None,
        'skin colour': None
        })
staff_df = pd.DataFrame(physical_attributes(hogwarts_staff))

# %%
# Scrape for the hogwarts students by house
driver.get('https://harrypotter.fandom.com/wiki/Hogwarts_Legacy')
house_names = ['Hufflepuff', 'Gryffindor', 'Ravenclaw', 'Slytherin']
houses_students = []
for name in house_names:
    if name == 'Gryffindor':
        xpaths = [f'//*[@id="mw-content-text"]/div/ul[{house_names.index(name)+2}]/li/a',f'//*[@id="mw-content-text"]/div/ul[{house_names.index(name)+2}]/li[10]/span']
    else:
        xpaths = [f'//*[@id="mw-content-text"]/div/ul[{house_names.index(name)+2}]/li/a',f'//*[@id="mw-content-text"]/div/ul[{house_names.index(name)+2}]/li[10]/span']
    for xpath in xpaths:
        houses = driver.find_elements(By.XPATH, xpath)
        for house in houses:
            houses_students.append({
                'house': name,
                'student': house.text,
                'url': house.get_attribute('href'),
                'species': None,
                'gender': None,
                'hair colour': None,
                'eye colour': None,
                'skin colour': None
            })
house_df = pd.DataFrame(physical_attributes(houses_students))

# %%
# Scraping for the historical wizards
driver.get('https://harrypotter.fandom.com/wiki/Hogwarts_Legacy')
wizard_titles = ['Keepers','Others']
historical_wizards = []
for wizard_title in wizard_titles:
    wizards = driver.find_elements(By.XPATH, f'//*[@id="mw-content-text"]/div/ul[{wizard_titles.index(wizard_title)+7}]/li/a')
    for wizard in wizards:
        historical_wizards.append({
            'title': wizard_title,
            'name': wizard.text,
            'url': wizard.get_attribute('href'),
            'species': None,
            'gender': None,
            'hair colour': None,
            'eye colour': None,
            'skin colour': None
        })
wizards_df = pd.DataFrame(physical_attributes(historical_wizards))

# %%
# Scraping for the villagers in Hogsmead
driver.get('https://harrypotter.fandom.com/wiki/Hogwarts_Legacy')
villagers = driver.find_elements(By.XPATH, '//*[@id="mw-content-text"]/div/ul[9]/li/a[1]')
hogsmead_villagers = []
for villager in villagers:
    hogsmead_villagers.append({
        'name': villager.text,
        'url':villager.get_attribute('href'),
        'species': None,
        'gender': None,
        'hair colour': None,
        'eye colour': None,
        'skin colour': None
        })
villagers_df = pd.DataFrame(physical_attributes(hogsmead_villagers))

# %%
# Scraping for enemies 
driver.get('https://harrypotter.fandom.com/wiki/Hogwarts_Legacy')
gang_members = driver.find_elements(By.XPATH, '//*[@id="mw-content-text"]/div/ul[10]/li/a[1]')
rookwood_gang = []
for gang_member in gang_members:
    rookwood_gang.append({
        'name': gang_member.text,
        'url':gang_member.get_attribute('href'),
        'species': None,
        'gender': None,
        'hair colour': None,
        'eye colour': None,
        'skin colour': None
        })
enemies_df = pd.DataFrame(physical_attributes(rookwood_gang))

# %%
# Scraping for the different locations 
driver.get('https://harrypotter.fandom.com/wiki/Hogwarts_Legacy')
locations = []
for index in range(1,8):
    main_locations = driver.find_elements(By.XPATH, f'//*[@id="mw-content-text"]/div/ul[12]/li[{index}]/a')
    town_locations = driver.find_elements(By.XPATH, f'//*[@id="mw-content-text"]/div/ul[12]/li[{index}]/ul/li')
    for main_location in main_locations:
        for town_location in town_locations:
            locations.append({
                'main_location':main_location.text,
                'town_location':town_location.text
            })
locations_df = pd.DataFrame(locations)

# %%
# Scraping for the Spells   
driver.get('https://harrypotter.fandom.com/wiki/Hogwarts_Legacy')

spells = []
for index in range(13,16):
    spell_list = driver.find_elements(By.XPATH, f'//*[@id="mw-content-text"]/div/ul[{index}]/li/a')
    for spell in spell_list:
        spells.append({
            'spell_name': spell.text,
            'url': spell.get_attribute('href'),
            'incantation': None,
            'type': None,
            'light': None,
            'effect': None
        })
spell_atts = ['incantation', 'type', 'hand movement','light', 'effect']
for atts in spell_atts:
    for value in spells:
        driver.get(value['url'])
        titles = driver.find_elements(By.XPATH, '//*[@id="mw-content-text"]/div/aside/section/div/h3')
        attributes = driver.find_elements(By.XPATH, f'//*[@id="mw-content-text"]/div/aside/section/div[{spell_atts.index(atts)+1}]/div')
        for title in titles:
            if title.text.lower() == atts:
                for attribute in attributes:
                    value[atts] = attribute.text
spells_df = pd.DataFrame(spells)

# %%
# Scraping for the Creatures
driver.get('https://harrypotter.fandom.com/wiki/Hogwarts_Legacy')
creatures = []
for index in range(1,5):
    creature_cats = driver.find_elements(By.XPATH, f'//*[@id="mw-content-text"]/div/ul[17]/li[{index}]/a')
    creature_list = driver.find_elements(By.XPATH, f'//*[@id="mw-content-text"]/div/ul[17]/li[{index}]/ul/li/a')
    for creature_cat in creature_cats:
        for creature in creature_list:
            creatures.append({
                'creature_type':creature_cat.text,
                'creatures':creature.text
            })
creatures_df = pd.DataFrame(creatures)

# %%
# Scrape for the hogwarts staff
driver.get('https://harrypotter.fandom.com/wiki/Hogwarts_Legacy')
others_list = driver.find_elements(By.XPATH, '//*[@id="mw-content-text"]/div/ul[11]/li/a')
other_characters = []
for people in others_list:
    other_characters.append({
        'name': people.text,
        'url':people.get_attribute('href'),
        'species': None,
        'gender': None,
        'hair colour': None,
        'eye colour': None,
        'skin colour': None
        })
others_df = pd.DataFrame(physical_attributes(other_characters))

# %%
data_dir = 'data'

if not os.path.exists(data_dir):
    os.makedirs(data_dir)

data = {
    'staff': staff_df,
    'house': house_df,
    'enemies': enemies_df,
    'wizards': wizards_df,
    'locations': locations_df,
    'villagers': villagers_df,
    'spells': spells_df,
    'creatures': creatures_df,
    'others': others_df
}

for name, df in data.items():
    filename = os.path.join(data_dir, f'{name}.csv')
    df.to_csv(filename, index_label=False)

# %% [markdown]
# # Cleaning the data

# %% [markdown]
# The following will be done to clean the data we have scraped
# - `url` on all the csvs will be dropped
# - Remove all the numbers and square brackets in the values in the columns
# - Remove the extra /n words in the names
# - Change the naming of some columns to have a uniform naming
# - Combine several columns to make a character dataframe
# - Check for null entries
# - Check for duplicated rows
# - Check for the data types
# - Check for spelling errors

# %%
enemies_df
# Out:
#                 name                                                url  \
# 0      Ackley Barnes  https://harrypotter.fandom.com/wiki/Ackley_Barnes
# 1    Catrin Haggarty  https://harrypotter.fandom.com/wiki/Catrin_Hag...
# 2  Theophilus Harlow  https://harrypotter.fandom.com/wiki/Theophilus...
# 3        Iona Morgan    https://harrypotter.fandom.com/wiki/Iona_Morgan
# 4    Victor Rookwood  https://harrypotter.fandom.com/wiki/Victor_Roo...
# 5    Silvanus Selwyn  https://harrypotter.fandom.com/wiki/Silvanus_S...
# 6    Tempeste Thorne  https://harrypotter.fandom.com/wiki/Tempeste_T...
# 7      Ailsa Travers  https://harrypotter.fandom.com/wiki/Ailsa_Travers
# 8     Gwendolyn Zhou  https://harrypotter.fandom.com/wiki/Gwendolyn_...
#
#     species     gender         hair colour eye colour skin colour
# 0  Human[1]    Male[1]            Black[1]   Brown[1]    Light[1]
# 1  Human[1]  Female[1]  Black (greying)[1]       None        None
# 2  Human[1]    Male[1]                None       None        None
# 3     Human     Female                None       None        None
# 4  Human[2]    Male[2]             Dark[2]       None        None
# 5     Human       Male                None       None        None
# 6     Human     Female               Brown       None        None
# 7  Human[1]  Female[1]            Black[1]   Brown[1]    White[1]
# 8  Human[2]  Female[2]            Black[2]       None        None

# %%
class DataClean:
    def __init__(self,df):
        self.df = df
        self.info = df.info()
        self.duplicates = df.duplicated().sum()
        self.missing = df.isna().sum()
        self.dtypes = df.dtypes
        self.shape = df.shape 
    def drop_col(self, col='url'):
        return self.df.drop(col, axis=1, inplace=True)

# %%
b = staff_df

# %%
# Out:
#    Unnamed: 0                    name  \
# 0           0  Phineas Nigellus Black
# 1           1         Matilda Weasley
# 2           2             Eleazar Fig
# 3           3             Aesop Sharp
# 4           4             Dinah Hecat
#
#                                                  url   species     gender  \
# 0  https://harrypotter.fandom.com/wiki/Phineas_Ni...     Human       Male
# 1  https://harrypotter.fandom.com/wiki/Matilda_We...       NaN        NaN
# 2    https://harrypotter.fandom.com/wiki/Eleazar_Fig  Human[4]    Male[4]
# 3    https://harrypotter.fandom.com/wiki/Aesop_Sharp  Human[4]    Male[4]
# 4    https://harrypotter.fandom.com/wiki/Dinah_Hecat  Human[4]  Female[4]
#
#   hair colour eye colour skin colour
# 0    Black[1]       Blue     Pale[1]
# 1         NaN        NaN         NaN
# 2     Grey[4]        NaN         NaN
# 3    Brown[4]        NaN         NaN
# 4     Grey[4]   Brown[5]    Light[4]

# %%
a = DataClean(b)
a.dtypes
# Out:
# Unnamed: 0      int64
# name           object
# url            object
# species        object
# gender         object
# hair colour    object
# eye colour     object
# skin colour    object
# dtype: object

# %%
house_df.head()
# Out:
#         house              student  \
# 0  Hufflepuff       Adelaide Oakes
# 1  Hufflepuff       Arthur Plummly
# 2  Hufflepuff   Charlotte Morrison
# 3  Hufflepuff  Evangeline Bardsley
# 4  Hufflepuff     Lenora Everleigh
#
#                                                  url   species     gender  \
# 0  https://harrypotter.fandom.com/wiki/Adelaide_O...     Human     Female
# 1  https://harrypotter.fandom.com/wiki/Arthur_Plu...      None   Black[4]
# 2  https://harrypotter.fandom.com/wiki/Charlotte_...     Human     Female
# 3  https://harrypotter.fandom.com/wiki/Evangeline...     Human     Female
# 4  https://harrypotter.fandom.com/wiki/Lenora_Eve...  Human[3]  Female[3]
#
#       hair colour eye colour skin colour
# 0  Light brown[3]       None        None
# 1        Brown[4]    Dark[4]        None
# 2           Black      Brown        Dark
# 3           Brown       None        None
# 4         Dark[3]    Dark[3]    Light[3]

# %%
staff_df
# Out:
#                       name                                                url  \
# 0   Phineas Nigellus Black  https://harrypotter.fandom.com/wiki/Phineas_Ni...
# 1          Matilda Weasley  https://harrypotter.fandom.com/wiki/Matilda_We...
# 2              Eleazar Fig    https://harrypotter.fandom.com/wiki/Eleazar_Fig
# 3              Aesop Sharp    https://harrypotter.fandom.com/wiki/Aesop_Sharp
# 4              Dinah Hecat    https://harrypotter.fandom.com/wiki/Dinah_Hecat
# 5          Mirabel Garlick  https://harrypotter.fandom.com/wiki/Mirabel_Ga...
# 6            Abraham Ronen  https://harrypotter.fandom.com/wiki/Abraham_Ronen
# 7           Cuthbert Binns  https://harrypotter.fandom.com/wiki/Cuthbert_B...
# 8                Bai Howin      https://harrypotter.fandom.com/wiki/Bai_Howin
# 9             Chiyo Kogawa   https://harrypotter.fandom.com/wiki/Chiyo_Kogawa
# 10             Mudiwa Onai    https://harrypotter.fandom.com/wiki/Mudiwa_Onai
# 11          Satyavati Shah  https://harrypotter.fandom.com/wiki/Satyavati_...
# 12          Noreen Blainey  https://harrypotter.fandom.com/wiki/Noreen_Bla...
# 13          Agnes Scribner  https://harrypotter.fandom.com/wiki/Agnes_Scri...
# 14            Gladwin Moon   https://harrypotter.fandom.com/wiki/Gladwin_Moon
#
#                           species     gender        hair colour eye colour  \
# 0                           Human       Male           Black[1]       Blue
# 1                            None       None               None       None
# 2                        Human[4]    Male[4]            Grey[4]       None
# 3                        Human[4]    Male[4]           Brown[4]       None
# 4                        Human[4]  Female[4]            Grey[4]   Brown[5]
# 5                        Human[4]  Female[4]             Red[4]       None
# 6                        Human[3]    Male[3]            6'1"[4]    Grey[3]
# 7   Human (formerly)[2]\nGhost[2]    Male[2]    White (balding)      Black
# 8                        Human[3]  Female[3]           Black[3]   Brown[3]
# 9                        Human[3]  Female[3]           Black[3]       None
# 10                       Human[1]  Female[1]           Black[2]   Brown[2]
# 11                       Human[2]  Female[2]  Black and grey[2]   Brown[2]
# 12                       Human[2]  Female[2]           Brown[4]    Blue[4]
# 13                       Human[2]  Female[2]            Grey[2]       None
# 14                       Human[3]    Male[3]           Black[3]    Dark[3]
#
#    skin colour
# 0      Pale[1]
# 1         None
# 2         None
# 3         None
# 4     Light[4]
# 5         None
# 6        Brown
# 7         Pale
# 8     Light[3]
# 9         None
# 10     Dark[2]
# 11    Light[2]
# 12    Light[4]
# 13        None
# 14        None

# %%
wizards_df.head()
# Out:
#      title               name  \
# 0  Keepers          San Bakar
# 1  Keepers   Niamh Fitzgerald
# 2  Keepers  Isidora Morganach
# 3  Keepers   Percival Rackham
# 4  Keepers   Charles Rookwood
#
#                                                  url   species     gender  \
# 0      https://harrypotter.fandom.com/wiki/San_Bakar     Human       Male
# 1  https://harrypotter.fandom.com/wiki/Niamh_Fitz...     Human     Female
# 2  https://harrypotter.fandom.com/wiki/Isidora_Mo...  Human[4]  Female[4]
# 3  https://harrypotter.fandom.com/wiki/Percival_R...     Human       Male
# 4  https://harrypotter.fandom.com/wiki/Charles_Ro...     Human       Male
#
#       hair colour eye colour skin colour
# 0            None   Light[1]        None
# 1  Light brown[4]    Blue[4]        None
# 2        Brown[4]       None        None
# 3        White[2]   Brown[2]        None
# 4           White       None        None

# %%
enemies_df.head()
# Out:
#                 name                                                url  \
# 0      Ackley Barnes  https://harrypotter.fandom.com/wiki/Ackley_Barnes
# 1    Catrin Haggarty  https://harrypotter.fandom.com/wiki/Catrin_Hag...
# 2  Theophilus Harlow  https://harrypotter.fandom.com/wiki/Theophilus...
# 3        Iona Morgan    https://harrypotter.fandom.com/wiki/Iona_Morgan
# 4    Victor Rookwood  https://harrypotter.fandom.com/wiki/Victor_Roo...
#
#     species     gender         hair colour eye colour skin colour
# 0  Human[1]    Male[1]            Black[1]   Brown[1]    Light[1]
# 1  Human[1]  Female[1]  Black (greying)[1]       None        None
# 2  Human[1]    Male[1]                None       None        None
# 3     Human     Female                None       None        None
# 4  Human[2]    Male[2]             Dark[2]       None        None

# %%
villagers_df
# Out:
#                   name                                                url  \
# 0         Thomas Brown   https://harrypotter.fandom.com/wiki/Thomas_Brown
# 1       Beatrice Green  https://harrypotter.fandom.com/wiki/Beatrice_G...
# 2        Augustus Hill  https://harrypotter.fandom.com/wiki/Augustus_Hill
# 3      Cassandra Mason  https://harrypotter.fandom.com/wiki/Cassandra_...
# 4   Gerbold Ollivander  https://harrypotter.fandom.com/wiki/Gerbold_Ol...
# 5           Ellie Peck     https://harrypotter.fandom.com/wiki/Ellie_Peck
# 6         Parry Pippin   https://harrypotter.fandom.com/wiki/Parry_Pippin
# 7    Calliope Snelling  https://harrypotter.fandom.com/wiki/Calliope_S...
# 8     Timothy Teasdale  https://harrypotter.fandom.com/wiki/Timothy_Te...
# 9     Thaddeus Travers  https://harrypotter.fandom.com/wiki/Thaddeus_T...
# 10        Jasper Trout   https://harrypotter.fandom.com/wiki/Jasper_Trout
# 11        Albie Weekes   https://harrypotter.fandom.com/wiki/Albie_Weekes
#
#      species     gender hair colour eye colour skin colour
# 0      Human       Male        Grey      Brown       Brown
# 1   Human[1]  Female[1]     Grey[2]    Grey[2]    Light[2]
# 2      Human       Male        None       None        None
# 3   Human[2]  Female[2]     Dark[2]       None        None
# 4   Human[2]    Male[2]        None       None        None
# 5   Human[1]  Female[1]    Black[1]   Brown[1]     Dark[1]
# 6      Human       Male       Brown       None        None
# 7      Human     Female       Brown      Brown       Light
# 8      Human       Male        None       None        None
# 9      Human       Male        None       None        None
# 10     Human       Male        None       None        None
# 11  Human[1]    Male[1]    Brown[1]   Brown[1]    Light[1]

# %%
others_df
# Out:
#                      name                                                url  \
# 0        Leopold Babcocke  https://harrypotter.fandom.com/wiki/Leopold_Ba...
# 1       Bardolph Beaumont  https://harrypotter.fandom.com/wiki/Bardolph_B...
# 2         Claire Beaumont  https://harrypotter.fandom.com/wiki/Claire_Bea...
# 3            Bloody Baron   https://harrypotter.fandom.com/wiki/Bloody_Baron
# 4             Effie Bones    https://harrypotter.fandom.com/wiki/Effie_Bones
# 5          Lethia Burbley  https://harrypotter.fandom.com/wiki/Lethia_Bur...
# 6            Agnes Coffey   https://harrypotter.fandom.com/wiki/Agnes_Coffey
# 7                    Deek           https://harrypotter.fandom.com/wiki/Deek
# 8                  Dorran         https://harrypotter.fandom.com/wiki/Dorran
# 9           Crispin Dunne  https://harrypotter.fandom.com/wiki/Crispin_Dunne
# 10                   Elek           https://harrypotter.fandom.com/wiki/Elek
# 11               Fastidio       https://harrypotter.fandom.com/wiki/Fastidio
# 12              Fat Friar      https://harrypotter.fandom.com/wiki/Fat_Friar
# 13               Fat Lady       https://harrypotter.fandom.com/wiki/Fat_Lady
# 14                 Feenky         https://harrypotter.fandom.com/wiki/Feenky
# 15             Miriam Fig     https://harrypotter.fandom.com/wiki/Miriam_Fig
# 16                Garnuff        https://harrypotter.fandom.com/wiki/Garnuff
# 17       Pádraic Haggarty  https://harrypotter.fandom.com/wiki/P%C3%A1dra...
# 18              Grey Lady  https://harrypotter.fandom.com/wiki/Helena_Rav...
# 19               Highwing       https://harrypotter.fandom.com/wiki/Highwing
# 20             Ernie Lark     https://harrypotter.fandom.com/wiki/Ernie_Lark
# 21         Fatimah Lawang  https://harrypotter.fandom.com/wiki/Fatimah_La...
# 22                 Lodgok         https://harrypotter.fandom.com/wiki/Lodgok
# 23         Bernard Ndiaye  https://harrypotter.fandom.com/wiki/Bernard_Nd...
# 24      Lord of the Shore  https://harrypotter.fandom.com/wiki/Lord_of_th...
# 25   Nearly Headless Nick  https://harrypotter.fandom.com/wiki/Nicholas_d...
# 26           George Osric   https://harrypotter.fandom.com/wiki/George_Osric
# 27          Rowland Oakes  https://harrypotter.fandom.com/wiki/Rowland_Oakes
# 28                 Peeves         https://harrypotter.fandom.com/wiki/Peeves
# 29                  Penny  https://harrypotter.fandom.com/wiki/Penny_(1890s)
# 30          Rohan Prakash  https://harrypotter.fandom.com/wiki/Rohan_Prakash
# 31           Mary Portman   https://harrypotter.fandom.com/wiki/Mary_Portman
# 32                 Ranrok         https://harrypotter.fandom.com/wiki/Ranrok
# 33     Alexandra Ricketts  https://harrypotter.fandom.com/wiki/Alexandra_...
# 34            Ruth Singer    https://harrypotter.fandom.com/wiki/Ruth_Singer
# 35            Jalal Sehmi    https://harrypotter.fandom.com/wiki/Jalal_Sehmi
# 36       Wigot Spitchwick  https://harrypotter.fandom.com/wiki/Wigot_Spit...
# 37      Eddie Thistlewood  https://harrypotter.fandom.com/wiki/Eddie_This...
# 38      Helen Thistlewood  https://harrypotter.fandom.com/wiki/Helen_This...
# 39         Nora Treadwell  https://harrypotter.fandom.com/wiki/Nora_Tread...
# 40        Priya Treadwell  https://harrypotter.fandom.com/wiki/Priya_Trea...
# 41           Ethel Wigley   https://harrypotter.fandom.com/wiki/Ethel_Wigley
# 42  Clementine Willardsey  https://harrypotter.fandom.com/wiki/Clementine...
#
#                           species     gender     hair colour eye colour  \
# 0                            None       None            None       None
# 1      Human (formerly)\nInferius       Male         Dark[2]       None
# 2                           Human     Female            None       None
# 3   Human[4] (formerly)\nGhost[4]    Male[4]            None   Light[5]
# 4                        Human[1]  Female[1]        Black[1]   Brown[1]
# 5                            None       None            None       None
# 6                        Human[2]  Female[2]  Light brown[2]   Brown[2]
# 7                            None       None            None       None
# 8                      Centaur[1]    Male[1]        Black[1]       None
# 9                        Human[1]    Male[1]            None       None
# 10                           None       None            None       None
# 11                 Poltergeist[2]    Male[2]            None       None
# 12     Human (formerly)\nGhost[4]    Male[4]     "Little"[4]       None
# 13                       Human[2]  Female[2]            None       None
# 14                   House-elf[1]  Female[1]         Grey[1]   Brown[1]
# 15                          Human     Female            None       None
# 16                      Goblin[2]    Male[2]            None   Light[2]
# 17                          Human       Male            Grey       None
# 18  Human[5] (formerly)\nGhost[5]  Female[5]            None       None
# 19                           None       None            None       None
# 20                           None       None            None       None
# 21                       Human[1]  Female[1]        Brown[1]   Brown[1]
# 22                      Goblin[1]    Male[1]         Grey[1]   Black[1]
# 23                          Human       Male            Bald      Brown
# 24                           None       None            None       None
# 25     Human (formerly)\nGhost[4]    Male[4]         Grey[5]       None
# 26                       Human[4]    Male[4]        Brown[4]   Brown[4]
# 27                       Human[1]    Male[1]        Brown[1]   Brown[1]
# 28                 Poltergeist[5]    Male[5]           Black   Black[6]
# 29                   House-elf[1]  Female[1]         Grey[1]   Brown[1]
# 30                           None       None            None       None
# 31                          Human     Female            None       None
# 32                      Goblin[1]    Male[1]         Grey[1]     Red[1]
# 33                          Human     Female           Brown      Brown
# 34                       Human[1]  Female[1]        Black[1]       None
# 35                       Human[2]    Male[2]            None       None
# 36                       Human[1]    Male[1]        Brown[1]   Brown[1]
# 37                           None       None            None       None
# 38                          Human     Female           Brown       None
# 39                       Human[1]  Female[1]         Dark[1]       None
# 40                       Human[1]  Female[1]            None       None
# 41                           None       None            None       None
# 42                       Human[2]  Female[2]        Brown[2]   Brown[2]
#
#    skin colour
# 0         None
# 1         None
# 2         None
# 3         None
# 4      Dark[1]
# 5         None
# 6     Light[2]
# 7         None
# 8         None
# 9         None
# 10        None
# 11        None
# 12    Light[5]
# 13        None
# 14    Light[1]
# 15        None
# 16        None
# 17        None
# 18        None
# 19        None
# 20        None
# 21    Light[1]
# 22    Light[1]
# 23        Dark
# 24        None
# 25        None
# 26    Light[4]
# 27    Light[1]
# 28  Pale White
# 29    Light[1]
# 30        None
# 31        None
# 32    Light[1]
# 33       Light
# 34        None
# 35        None
# 36    Light[1]
# 37        None
# 38        None
# 39        None
# 40        None
# 41        None
# 42    Light[2]
